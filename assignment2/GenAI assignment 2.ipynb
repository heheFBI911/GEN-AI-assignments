# %%
pip install google-generativeai

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyBodV4LP5pgLPsfa2hU2YzpMsikpVZzOaU")

# %%
model = genai.GenerativeModel("gemini-pro")

# %%
# **Function to Call Google Gemini API**
def gemini_prompt(prompt):
    response = model.generate_content(prompt)
    return response.text

# %%
# Define prompt (Interview Approach)
prompt = """
I will ask you a series of questions about Quantum Computing.
1. What is the basic principle of Quantum Computing?
2. How does it differ from Classical Computing?
3. Can you give a simple real-world analogy?
4. What are its practical applications?
"""

# %%
# Generate response
response = model.generate_content(prompt)
print("Interview Approach:\n", response.text)
# Out:
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 711.57ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-13-b068a7ef14c5> in <cell line: 0>()
#       1 # Generate response
# ----> 2 response = model.generate_content(prompt)
#       3 print("Interview Approach:\n", response.text)
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# ...

# %%
import google.generativeai as genai

# ... (other code) ...

# Generate response
# Instead of directly using 'gemini-pro', try using 'models/gemini-pro'
response = model.generate_content(prompt, model="models/gemini-pro")
print("Interview Approach:\n", response.text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-e66870d5d909> in <cell line: 0>()
#       5 # Generate response
#       6 # Instead of directly using 'gemini-pro', try using 'models/gemini-pro'
# ----> 7 response = model.generate_content(prompt, model="models/gemini-pro")
#       8 print("Interview Approach:\n", response.text)
#
# TypeError: GenerativeModel.generate_content() got an unexpected keyword argument 'model'

# %%
import google.generativeai as genai

# ... (other code) ...

# Generate response
# Remove the 'model' argument from generate_content
response = model.generate_content(prompt)
print("Interview Approach:\n", response.text)
# Out:
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 785.91ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-9-7c6e2fd09215> in <cell line: 0>()
#       5 # Generate response
#       6 # Remove the 'model' argument from generate_content
# ----> 7 response = model.generate_content(prompt)
#       8 print("Interview Approach:\n", response.text)
#
# /usr/local/lib/python3.11/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
# ...
